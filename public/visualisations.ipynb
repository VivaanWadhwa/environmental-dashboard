# %%
import pandas as pd
import re
from difflib import SequenceMatcher
from collections import defaultdict

# %%
## Path for restaurant data
restaurant_names = ["Gather24-25", "OK24-25", "Totem24-25"]
restaurant_data_paths = [f"Labelled_Data_{restaurant_name}_for_nutrislice.csv" for restaurant_name in restaurant_names]

# %%
results = []
for restaurant_name, restaurant_data_path in zip(restaurant_names, restaurant_data_paths):
    df = pd.read_csv(restaurant_data_path)
    df["restaurant"] = restaurant_name
    results.append(df)

results = pd.concat(results)
results.drop_duplicates(inplace=True)
results.reset_index(drop=True, inplace=True)
results
# Out:
#      Optimum Control ID                 OC Description      SalesGroup  \
# 0               R-73669  DEL|smoothie| mango pineapple     GV - DELISH
# 1               R-56613   DEL|Smoothie|Almonds forever     GV - DELISH
# 2               R-44306    DEL|Smoothie|Banana Matcha      GV - DELISH
# 3               R-43697  DEL|Smoothie|Blueberry Boost      GV - DELISH
# 4               R-46074    DEL|Smoothie|Bna Almnd Buta     GV - DELISH
# ...                 ...                            ...             ...
# 1151            P-26062            SALSA|Pico de Gallo            PREP
# 1152            P-33438                   SAUCE|Hummus            PREP
# 1153            P-35848           SAUCE|Tzatziki Sauce            PREP
# 1154             I-1033   BREAD PITA GREEK THK 7IN TFC     BAKED GOODS
# 1155            I-57554                CRACKER BRETON*  FOOD - GROCERY
#
#      Combined Label    Red  Yellow  Green  GHG Emission (g)  N lost (g)  \
# 0             Green  False   False   True         77.151358    0.375085
# 1            Yellow  False    True  False        324.658690    1.122366
# 2             Green  False   False   True        284.936566    1.539948
# 3               Red   True   False  False       1649.829015    6.896554
# 4             Green  False   False   True        169.432593    0.488466
# ...             ...    ...     ...    ...               ...         ...
# 1151          Green  False   False   True      21005.354382  257.200874
# 1152          Green  False   False   True      18485.853000   59.238300
# 1153         Yellow  False    True  False       6659.783239   61.316278
# 1154          Green  False   False   True          0.129412    1.258000
# 1155          Green  False   False   True          0.304500    2.960000
#
#       Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0           0.148062                        0.59
# 1           0.675339                      101.87
# 2           0.554830                       71.85
# 3           1.263809                      281.74
# 4           0.549266                        2.28
# ...              ...                         ...
# 1151       11.194883                     2088.44
# 1152      108.363310                     1946.67
# 1153        6.240908                      618.01
# 1154        0.000416                        0.04
# 1155        0.000978                        0.08
#
#       Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  \
# 0                              1.92                    22.04
# 1                           7213.85                    94.72
# 2                           4270.05                    78.06
# 3                          11794.01                   452.01
# 4                            128.70                    46.42
# ...                             ...                      ...
# 1151                      118743.83                    70.02
# 1152                      137192.99                   123.24
# 1153                       29369.76                   221.99
# 1154                           1.09                     0.15
# 1155                           2.56                     0.15
#
#       N lost (g) / 100g  Freshwater Withdrawals (L) / 100g  \
# 0                  0.11                               0.17
# 1                  0.33                              29.72
# 2                  0.42                              19.68
# 3                  1.89                              77.19
# 4                  0.13                               0.62
# ...                 ...                                ...
# 1151               0.86                               6.96
# 1152               0.39                              12.98
# 1153               2.04                              20.60
# 1154               1.48                               0.05
# 1155               1.48                               0.04
#
#       Stress-Weighted Water Use (L) / 100g  Land Use (m^2) / 100g   restaurant
# 0                                     0.55                   0.04  Gather24-25
# 1                                  2104.70                   0.20  Gather24-25
# 2                                  1169.88                   0.15  Gather24-25
# 3                                  3231.24                   0.35  Gather24-25
# 4                                    35.26                   0.15  Gather24-25
# ...                                    ...                    ...          ...
# 1151                                395.81                   0.04   Totem24-25
# 1152                                914.62                   0.72   Totem24-25
# 1153                                978.99                   0.21   Totem24-25
# 1154                                  1.28                   0.00   Totem24-25
# 1155                                  1.28                   0.00   Totem24-25
#
# [1156 rows x 18 columns]

# %%
def analyze_recipes(df, column_name='OC Description'):
    """
    Analyze recipes and categorize them as animal-based or plant-based.
    Plant-based recipes must not contain any animal-based ingredients.
    
    Parameters:
    df (pandas.DataFrame): DataFrame containing recipe information
    column_name (str): Name of the column containing recipe descriptions
    
    Returns:
    tuple: (animal_recipes DataFrame, plant_recipes DataFrame, stats dictionary)
    """
    # Define comprehensive ingredient lists
    animal_based = [
        'beef', 'chicken', 'lamb', 'pork', 'fish', 'egg', 'salmon',
        'tuna', 'shrimp', 'turkey', 'meat', 'duck', 'bacon',
        'sausage', 'seafood', 'shellfish', "omelette", 'omelet'
    ]
    
    plant_based = [
        'tofu', 'lentil', 'vegan', 'plant', 'miso', 'tempeh',
        'seitan', 'chickpea', 'bean', 'quinoa', 'vegetarian',
        'soy', 'mushroom', 'veggie', 'falafel', 'hummus',
        'jackfruit', 'beyond', 'impossible'
    ]
    
    try:
        # Ensure the column exists
        if column_name not in df.columns:
            raise ValueError(f"Column '{column_name}' not found in DataFrame")
            
        # Convert column to string type and fill NaN values
        df[column_name] = df[column_name].astype(str).fillna('')
        
        # Create regex patterns with word boundaries
        animal_pattern = r'\b(' + '|'.join(animal_based) + r')\b'
        plant_pattern = r'\b(' + '|'.join(plant_based) + r')\b'
        
        # Filter recipes
        animal_recipes = df[df[column_name].str.contains(
            animal_pattern, 
            case=False, 
            regex=True
        )].copy()
        
        # For plant-based recipes:
        # 1. Must contain plant-based keywords
        # 2. Must NOT contain animal-based keywords
        plant_recipes = df[
            df[column_name].str.contains(
                plant_pattern,
                case=False,
                regex=True
            ) &
            ~df[column_name].str.contains(
                animal_pattern,
                case=False,
                regex=True
            )
        ].copy()
        
        # Add category labels
        animal_recipes['category'] = 'animal_based'
        plant_recipes['category'] = 'plant_based'
        
        # Calculate statistics
        stats = {
            'total_recipes': len(df),
            'animal_based_count': len(animal_recipes),
            'strict_plant_based_count': len(plant_recipes),
            'animal_based_percentage': round(len(animal_recipes) / len(df) * 100, 2),
            'strict_plant_based_percentage': round(len(plant_recipes) / len(df) * 100, 2),
            'uncategorized_count': len(df) - len(animal_recipes) - len(plant_recipes),
            'uncategorized_percentage': round((len(df) - len(animal_recipes) - len(plant_recipes)) / len(df) * 100, 2)
        }
        
        # Add matched keywords columns
        def find_matched_keywords(text, keywords):
            matches = [word for word in keywords if re.search(r'\b' + re.escape(word) + r'\b', text, re.IGNORECASE)]
            return ', '.join(matches) if matches else ''
        
        animal_recipes['matched_ingredients'] = animal_recipes[column_name].apply(
            lambda x: find_matched_keywords(x, animal_based)
        )
        plant_recipes['matched_ingredients'] = plant_recipes[column_name].apply(
            lambda x: find_matched_keywords(x, plant_based)
        )
        
        return animal_recipes, plant_recipes, stats
        
    except Exception as e:
        print(f"Error analyzing recipes: {str(e)}")
        return pd.DataFrame(), pd.DataFrame(), {}

# %%
animal_recipes, plant_recipes, stats = analyze_recipes(results)
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_5428/992152671.py:40: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   animal_recipes = df[df[column_name].str.contains(
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_5428/992152671.py:50: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[column_name].str.contains(
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_5428/992152671.py:55: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ~df[column_name].str.contains(

# %%
animal_recipes
# Out:
#      Optimum Control ID                  OC Description  \
# 16              R-14085        DIM SUM|Bun|BBQ Pork (1)
# 17              R-37741         DIM SUM|Bun|Chicken (1)
# 34              R-65761    FF|Bowl|Poached Egg Zuc.|AAD
# 43              R-70058         FF|Omelette|3Cheese|AAD
# 44              R-70095   FF|Omelette|Mushroom&Ched|AAD
# ...                 ...                             ...
# 1090            R-61979         HS|Tuscan Chicken|PLATE
# 1105            R-55967           RTS|Egg|Ajitama Ramen
# 1125            R-73508  SOUP|Goodly|Beef Barley Shroom
# 1126            R-73213        SOUP|Goodly|Chicken Orzo
# 1139            P-67662         BATCH|Smoked Salmon Dip
#
#                    SalesGroup Combined Label    Red  Yellow  Green  \
# 16               GV - DIM SUM            Red   True   False  False
# 17               GV - DIM SUM          Green  False   False   True
# 34          GV FRESH FARE DAY          Green  False   False   True
# 43    GV FRESH FARE BREAKFAST            Red   True   False  False
# 44    GV FRESH FARE BREAKFAST            Red   True   False  False
# ...                       ...            ...    ...     ...    ...
# 1090           FT HOMESKILLET         Yellow  False    True  False
# 1105                    FEAST            Red   True   False  False
# 1125                    FEAST            Red   True   False  False
# 1126                    FEAST            Red   True   False  False
# 1139                      NaN            Red   True   False  False
#
#       GHG Emission (g)  N lost (g)  Land Use (m^2)  \
# 16          482.545000    6.273000        0.000000
# 17          288.096875    5.593375        0.000000
# 34          644.382248    4.382055        1.217309
# 43         1573.110977   20.086341        2.389152
# 44          967.823941   13.822301        1.728308
# ...                ...         ...             ...
# 1090       1133.996739   21.186884        2.255985
# 1105        561.196213    9.272708        0.999513
# 1125      12403.890000   98.850000       37.935000
# 1126       1319.880000   35.040000        3.453000
# 1139       3390.391613   33.988709        4.018596
#
#       Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 16                         94.75                        2850.24
# 17                         46.76                        1048.22
# 34                        184.00                        1720.02
# 43                        267.90                       11401.72
# 44                        160.67                        5805.33
# ...                          ...                            ...
# 1090                      114.65                        3643.17
# 1105                       90.74                        2661.74
# 1125                      503.16                       18392.70
# 1126                      111.09                         100.05
# 1139                      578.02                       23240.34
#
#       GHG Emission (g) / 100g  N lost (g) / 100g  \
# 16                     567.70               7.38
# 17                     198.69               3.86
# 34                     179.00               1.22
# 43                     555.87               7.10
# 44                     406.65               5.81
# ...                       ...                ...
# 1090                   331.58               6.19
# 1105                  1122.39              18.55
# 1125                  4134.63              32.95
# 1126                   439.96              11.68
# 1139                   584.55               5.86
#
#       Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 16                               111.47                               3353.22
# 17                                32.25                                722.91
# 34                                51.11                                477.78
# 43                                94.66                               4028.88
# 44                                67.51                               2439.21
# ...                                 ...                                   ...
# 1090                              33.52                               1065.25
# 1105                             181.48                               5323.48
# 1125                             167.72                               6130.90
# 1126                              37.03                                 33.35
# 1139                              99.66                               4006.96
#
#       Land Use (m^2) / 100g   restaurant      category matched_ingredients
# 16                     0.00  Gather24-25  animal_based                pork
# 17                     0.00  Gather24-25  animal_based             chicken
# 34                     0.34  Gather24-25  animal_based                 egg
# 43                     0.84  Gather24-25  animal_based            omelette
# 44                     0.73  Gather24-25  animal_based            omelette
# ...                     ...          ...           ...                 ...
# 1090                   0.66   Totem24-25  animal_based             chicken
# 1105                   2.00   Totem24-25  animal_based                 egg
# 1125                  12.64   Totem24-25  animal_based                beef
# 1126                   1.15   Totem24-25  animal_based             chicken
# 1139                   0.69   Totem24-25  animal_based              salmon
#
# [273 rows x 20 columns]

# %%
def find_similar_recipes(animal_recipes, plant_recipes, similarity_threshold=0.6):
    """
    Find similar recipe pairs between animal-based and plant-based categories.
    
    Parameters:
    animal_recipes (pandas.DataFrame): DataFrame of animal-based recipes
    plant_recipes (pandas.DataFrame): DataFrame of plant-based recipes
    similarity_threshold (float): Minimum similarity score to consider recipes as similar
    
    Returns:
    pandas.DataFrame: DataFrame containing similar recipe pairs and their dish types
    """
    
    def extract_dish_type(description):
        """Extract the basic dish type from a recipe description."""
        # Common dish types to look for
        dish_types = {
            'taco': ['taco', 'tacos'],
            'curry': ['curry', 'curries'],
            'burger': ['burger', 'burgers'],
            'soup': ['soup', 'soups', 'stew', 'stews'],
            'pasta': ['pasta', 'noodle', 'noodles', 'spaghetti', 'fettuccine'],
            'sandwich': ['sandwich', 'sandwiches'],
            'bowl': ['bowl', 'bowls'],
            'stir fry': ['stir fry', 'stir-fry'],
            'salad': ['salad', 'salads'],
            'wrap': ['wrap', 'wraps'],
            'rice': ['rice', 'risotto'],
            'pizza': ['pizza', 'pizzas'],
            'casserole': ['casserole', 'bake', 'hotdish']
        }
        
        description = description.lower()
        for dish_type, variants in dish_types.items():
            for variant in variants:
                if re.search(r'\b' + re.escape(variant) + r'\b', description):
                    return dish_type
        return 'other'

    def calculate_similarity(desc1, desc2):
        """Calculate similarity between two recipe descriptions."""
        # Remove common words that might interfere with similarity calculation
        common_words = {'and', 'with', 'the', 'a', 'an', 'in', 'on', 'at', 'to', 'for', 'of'}
        desc1 = ' '.join([word for word in desc1.lower().split() if word not in common_words])
        desc2 = ' '.join([word for word in desc2.lower().split() if word not in common_words])
        return SequenceMatcher(None, desc1, desc2).ratio()

    try:
        # Extract dish types for both categories
        animal_recipes['dish_type'] = animal_recipes['OC Description'].apply(extract_dish_type)
        plant_recipes['dish_type'] = plant_recipes['OC Description'].apply(extract_dish_type)
        
        # Initialize lists to store similar pairs
        similar_pairs = []
        
        # Group recipes by dish type
        animal_by_type = defaultdict(list)
        plant_by_type = defaultdict(list)
        
        for _, row in animal_recipes.iterrows():
            animal_by_type[row['dish_type']].append(row)
        for _, row in plant_recipes.iterrows():
            plant_by_type[row['dish_type']].append(row)
        
        # Find similar pairs within each dish type
        for dish_type in set(animal_by_type.keys()) & set(plant_by_type.keys()):
            for animal_recipe in animal_by_type[dish_type]:
                for plant_recipe in plant_by_type[dish_type]:
                    similarity = calculate_similarity(
                        animal_recipe['OC Description'],
                        plant_recipe['OC Description']
                    )
                    
                    if similarity >= similarity_threshold:
                        similar_pairs.append({
                            'dish_type': dish_type,
                            'animal_recipe': animal_recipe['OC Description'],
                            'animal_recipe_ID': animal_recipe['Optimum Control ID'],
                            'animal_ingredients': animal_recipe.get('matched_ingredients', ''),
                            'plant_recipe': plant_recipe['OC Description'],
                            'plant_recipe_ID': plant_recipe['Optimum Control ID'],
                            'plant_ingredients': plant_recipe.get('matched_ingredients', ''),
                            'similarity_score': round(similarity, 3)
                        })
        
        # Create DataFrame from similar pairs
        similar_df = pd.DataFrame(similar_pairs)
        
        # Sort by dish type and similarity score
        if not similar_df.empty:
            similar_df = similar_df.sort_values(
                ['dish_type', 'similarity_score'], 
                ascending=[True, False]
            )
            
            # Add summary statistics
            stats = {
                'total_similar_pairs': len(similar_df),
                'unique_dish_types': len(similar_df['dish_type'].unique()),
                'avg_similarity_score': round(similar_df['similarity_score'].mean(), 3),
                'dish_type_counts': similar_df['dish_type'].value_counts().to_dict()
            }
        else:
            stats = {
                'total_similar_pairs': 0,
                'unique_dish_types': 0,
                'avg_similarity_score': 0,
                'dish_type_counts': {}
            }
            
        return similar_df, stats

    except Exception as e:
        print(f"Error finding similar recipes: {str(e)}")
        return pd.DataFrame(), {}

# %%
similar_recipes, stats = find_similar_recipes(animal_recipes, plant_recipes, 0.7)

# %%
similar_recipes
# Out:
#    dish_type                   animal_recipe animal_recipe_ID  \
# 29      bowl     HS|Bowl|Coconut Miso Salmon          R-73323
# 28      bowl   CLV|Chicken Tikka Masala|BOWL          R-68226
# 2     burger   GRL|Burger|swiss chz|Pork|AAD          R-50118
# 1     burger           GRL|Burger|Salmon|AAD          R-44931
# 0     burger           GRL|Burger|Salmon|AAD          R-44931
# 3     burger     GRL|Chicken Burger|Maui|AAD          R-56454
# 27     curry     SQR|Thai Green Fish Curry+1          R-57350
# 18     other      ALF|Flatbread|Shrimp Pesto          R-61742
# 17     other   HC|Lemon Olive Oil Salmon|AAD          R-62715
# 19     other   SQR|Citrus Soy Pork Skewer +1          R-62631
# 16     other   FLX|Spicy Soy Salmon 100g|AAD          R-61967
# 20     other          SQR|Spicy Soy Salmon+1          R-41085
# 24     other  HS|Sesame Ginger Chicken|PLATE          R-73143
# 15     other            FLX|Shoyu Salmon|AAD          R-69236
# 21     other      CLV|Chicken Vindaloo|PLATE          R-44403
# 23     other     DNR|Omelette|Mushroom swiss          R-50556
# 13     other          FLX|Butter chicken|AAD          R-56775
# 22     other      CLV|Chicken Vindaloo|PLATE          R-44403
# 14     other           FLX|Shoyu Chicken|AAD          R-45153
# 30     pasta        HS|Pasta|Beef Stroganoff          R-50007
# 25     salad              SAND|Chicken Salad          R-68083
# 26     salad                  SAND|Egg Salad          R-71946
# 5   sandwich          SANDWICH|Chicken Salad          R-68083
# 6   sandwich              SANDWICH|Egg Salad          R-71946
# 8   sandwich   HC| Bfast Sandwich|Turkey&Egg          R-44823
# 4   sandwich    SANDWICH|Chicken Caesar Wrap          R-68143
# 7   sandwich              SANDWICH|Egg Salad          R-71946
# 9       taco      BNO|Taco|Chicken Tinga|2PC          R-67551
# 11      taco     BNO|Taco|Fried Chicken|2 PC          R-61877
# 10      taco      BNO|Taco|Chicken Tinga|2PC          R-67551
# 12      taco     BNO|Taco|Fried Chicken|2 PC          R-61877
#
#    animal_ingredients                   plant_recipe plant_recipe_ID  \
# 29             salmon      HS|Bowl|Coconut Miso Tofu         R-73499
# 28            chicken     CLV|Tofu Tikka Masala|BOWL         R-68229
# 2                pork  GRL|Burger|Swiss Mushroom|AAD         R-70492
# 1              salmon  GRL|Burger|Swiss Mushroom|AAD         R-70492
# 0              salmon       GRL|Burger|Jackfruit|AAD         R-53579
# 3             chicken       GRL|Burger|Jackfruit|AAD         R-53579
# 27               fish     SQR|TOFU|Thai Green Curry          R-49260
# 18             shrimp   ALF|Flatbread|Mushroom Pesto         R-61779
# 17             salmon    HC|Lemon Olive Oil Tofu|AAD         R-73542
# 19               pork  SQR|Citrus Mushroom Skewer +1         R-62639
# 16             salmon    FLX|Spicy Soy tofu 150g|AAD         R-62288
# 20             salmon           SQR|Spicy Soy Tofu+1         R-41089
# 24            chicken    HS|Sesame Ginger Tofu|PLATE         R-62138
# 15             salmon             FLX|Shoyu tofu|AAD         R-61956
# 21            chicken      FLX|Chickpea Vindaloo|AAD         R-56827
# 23           omelette       GRL|Crepe|Mushroom Swiss         R-67745
# 13            chicken            FLX|Butter tofu|AAD         R-57264
# 22            chicken          GLB|Chickpea Vindaloo         R-56827
# 14            chicken             FLX|Shoyu tofu|AAD         R-61956
# 30               beef   HS|Pasta|Mushroom Stroganoff         R-67287
# 25            chicken            SAND|Chickpea Salad         R-68078
# 26                egg            SAND|Chickpea Salad         R-68078
# 5             chicken        SANDWICH|Chickpea Salad         R-68078
# 6                 egg        SANDWICH|Chickpea Salad         R-68078
# 8         egg, turkey        HC|Bfast Sandwich|VEGAN         R-69443
# 4             chicken        SANDWICH|Chickpea Salad         R-68078
# 7                 egg               SANDWICH|Falafel         R-68079
# 9             chicken         BNO|Taco|Chickpea|2 pc         R-67695
# 11            chicken         BNO|Taco|Chickpea|2 pc         R-67695
# 10            chicken  BNO|Taco|Jackfruit Tinga|2 PC         R-71310
# 12            chicken  BNO|Taco|Jackfruit Tinga|2 PC         R-71310
#
#    plant_ingredients  similarity_score
# 29        tofu, miso             0.846
# 28              tofu             0.800
# 2           mushroom             0.793
# 1           mushroom             0.720
# 0          jackfruit             0.711
# 3          jackfruit             0.706
# 27              tofu             0.769
# 18          mushroom             0.889
# 17              tofu             0.857
# 19          mushroom             0.828
# 16         tofu, soy             0.821
# 20         tofu, soy             0.810
# 24              tofu             0.807
# 15              tofu             0.789
# 21          chickpea             0.745
# 23          mushroom             0.745
# 13              tofu             0.732
# 22          chickpea             0.723
# 14              tofu             0.718
# 30          mushroom             0.769
# 25          chickpea             0.919
# 26          chickpea             0.727
# 5           chickpea             0.933
# 6           chickpea             0.780
# 8              vegan             0.769
# 4           chickpea             0.745
# 7            falafel             0.706
# 9           chickpea             0.833
# 11          chickpea             0.816
# 10         jackfruit             0.764
# 12         jackfruit             0.714

# %%
visualisations = similar_recipes[["animal_recipe", "animal_recipe_ID", "plant_recipe", "plant_recipe_ID"]]
visualisations
# Out:
#                      animal_recipe animal_recipe_ID  \
# 29     HS|Bowl|Coconut Miso Salmon          R-73323
# 28   CLV|Chicken Tikka Masala|BOWL          R-68226
# 2    GRL|Burger|swiss chz|Pork|AAD          R-50118
# 1            GRL|Burger|Salmon|AAD          R-44931
# 0            GRL|Burger|Salmon|AAD          R-44931
# 3      GRL|Chicken Burger|Maui|AAD          R-56454
# 27     SQR|Thai Green Fish Curry+1          R-57350
# 18      ALF|Flatbread|Shrimp Pesto          R-61742
# 17   HC|Lemon Olive Oil Salmon|AAD          R-62715
# 19   SQR|Citrus Soy Pork Skewer +1          R-62631
# 16   FLX|Spicy Soy Salmon 100g|AAD          R-61967
# 20          SQR|Spicy Soy Salmon+1          R-41085
# 24  HS|Sesame Ginger Chicken|PLATE          R-73143
# 15            FLX|Shoyu Salmon|AAD          R-69236
# 21      CLV|Chicken Vindaloo|PLATE          R-44403
# 23     DNR|Omelette|Mushroom swiss          R-50556
# 13          FLX|Butter chicken|AAD          R-56775
# 22      CLV|Chicken Vindaloo|PLATE          R-44403
# 14           FLX|Shoyu Chicken|AAD          R-45153
# 30        HS|Pasta|Beef Stroganoff          R-50007
# 25              SAND|Chicken Salad          R-68083
# 26                  SAND|Egg Salad          R-71946
# 5           SANDWICH|Chicken Salad          R-68083
# 6               SANDWICH|Egg Salad          R-71946
# 8    HC| Bfast Sandwich|Turkey&Egg          R-44823
# 4     SANDWICH|Chicken Caesar Wrap          R-68143
# 7               SANDWICH|Egg Salad          R-71946
# 9       BNO|Taco|Chicken Tinga|2PC          R-67551
# 11     BNO|Taco|Fried Chicken|2 PC          R-61877
# 10      BNO|Taco|Chicken Tinga|2PC          R-67551
# 12     BNO|Taco|Fried Chicken|2 PC          R-61877
#
#                      plant_recipe plant_recipe_ID
# 29      HS|Bowl|Coconut Miso Tofu         R-73499
# 28     CLV|Tofu Tikka Masala|BOWL         R-68229
# 2   GRL|Burger|Swiss Mushroom|AAD         R-70492
# 1   GRL|Burger|Swiss Mushroom|AAD         R-70492
# 0        GRL|Burger|Jackfruit|AAD         R-53579
# 3        GRL|Burger|Jackfruit|AAD         R-53579
# 27     SQR|TOFU|Thai Green Curry          R-49260
# 18   ALF|Flatbread|Mushroom Pesto         R-61779
# 17    HC|Lemon Olive Oil Tofu|AAD         R-73542
# 19  SQR|Citrus Mushroom Skewer +1         R-62639
# 16    FLX|Spicy Soy tofu 150g|AAD         R-62288
# 20           SQR|Spicy Soy Tofu+1         R-41089
# 24    HS|Sesame Ginger Tofu|PLATE         R-62138
# 15             FLX|Shoyu tofu|AAD         R-61956
# 21      FLX|Chickpea Vindaloo|AAD         R-56827
# 23       GRL|Crepe|Mushroom Swiss         R-67745
# 13            FLX|Butter tofu|AAD         R-57264
# 22          GLB|Chickpea Vindaloo         R-56827
# 14             FLX|Shoyu tofu|AAD         R-61956
# 30   HS|Pasta|Mushroom Stroganoff         R-67287
# 25            SAND|Chickpea Salad         R-68078
# 26            SAND|Chickpea Salad         R-68078
# 5         SANDWICH|Chickpea Salad         R-68078
# 6         SANDWICH|Chickpea Salad         R-68078
# 8         HC|Bfast Sandwich|VEGAN         R-69443
# 4         SANDWICH|Chickpea Salad         R-68078
# 7                SANDWICH|Falafel         R-68079
# 9          BNO|Taco|Chickpea|2 pc         R-67695
# 11         BNO|Taco|Chickpea|2 pc         R-67695
# 10  BNO|Taco|Jackfruit Tinga|2 PC         R-71310
# 12  BNO|Taco|Jackfruit Tinga|2 PC         R-71310

# %%
# Add new columns for each emission metric in animal and plant-based recipes
for metric in ["GHG Emission (g) / 100g", "N lost (g) / 100g", "Freshwater Withdrawals (L) / 100g", 
               "Stress-Weighted Water Use (L) / 100g", "Land Use (m^2) / 100g"]:
    
    # Extract emissions for animal-based recipes
    visualisations[f"animal_{metric}"] = visualisations['animal_recipe_ID'].apply(
        lambda recipe_id: results.loc[results['Optimum Control ID'] == recipe_id, metric].values[0]
    )
    
    # Extract emissions for plant-based recipes
    visualisations[f"plant_{metric}"] = visualisations['plant_recipe_ID'].apply(
        lambda recipe_id: results.loc[results['Optimum Control ID'] == recipe_id, metric].values[0]
    )

# Show the updated DataFrame
visualisations.head()
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_5428/185445706.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visualisations[f"animal_{metric}"] = visualisations['animal_recipe_ID'].apply(
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_5428/185445706.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visualisations[f"plant_{metric}"] = visualisations['plant_recipe_ID'].apply(
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_5428/185445706.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visualisations[f"animal_{metric}"] = visualisations['animal_recipe_ID'].apply(
#                     animal_recipe animal_recipe_ID  \
# 29    HS|Bowl|Coconut Miso Salmon          R-73323
# 28  CLV|Chicken Tikka Masala|BOWL          R-68226
# 2   GRL|Burger|swiss chz|Pork|AAD          R-50118
# 1           GRL|Burger|Salmon|AAD          R-44931
# 0           GRL|Burger|Salmon|AAD          R-44931
#
#                      plant_recipe plant_recipe_ID  \
# 29      HS|Bowl|Coconut Miso Tofu         R-73499
# 28     CLV|Tofu Tikka Masala|BOWL         R-68229
# 2   GRL|Burger|Swiss Mushroom|AAD         R-70492
# 1   GRL|Burger|Swiss Mushroom|AAD         R-70492
# 0        GRL|Burger|Jackfruit|AAD         R-53579
#
#     animal_GHG Emission (g) / 100g  plant_GHG Emission (g) / 100g  \
# 29                          328.88                         147.49
# 28                          417.22                         204.23
# 2                           550.19                        1523.06
# 1                           349.97                        1523.06
# 0                           349.97                         131.20
#
#     animal_N lost (g) / 100g  plant_N lost (g) / 100g  \
# 29                      3.50                     0.58
# 28                      5.08                     1.07
# 2                       6.96                    12.30
# 1                       4.24                    12.30
# 0                       4.24                     0.86
#
#     animal_Freshwater Withdrawals (L) / 100g  \
# 29                                     92.00
# 28                                     76.63
# 2                                     104.38
# 1                                      95.86
# 0                                      95.86
#
#     plant_Freshwater Withdrawals (L) / 100g  \
# 29                                    23.09
# 28                                    38.63
# 2                                     78.11
# 1                                     78.11
# 0                                     14.18
#
#     animal_Stress-Weighted Water Use (L) / 100g  \
# 29                                       542.99
# 28                                      1785.27
# 2                                       3478.62
# 1                                       1028.02
# 0                                       1028.02
#
#     plant_Stress-Weighted Water Use (L) / 100g  animal_Land Use (m^2) / 100g  \
# 29                                      163.86                          0.47
# 28                                      595.57                          0.87
# 2                                      2925.84                          1.15
# 1                                      2925.84                          0.70
# 0                                       434.40                          0.70
#
#     plant_Land Use (m^2) / 100g
# 29                         0.27
# 28                         0.36
# 2                          4.65
# 1                          4.65
# 0                          0.30

# %%
# Filter out rows where animal GHG emissions are less than plant GHG emissions
def filter_emissions(row):
    """
    Filter out rows where animal emissions are less than plant emissions.

    If more than one emission metric is lower for animal-based recipes compared to plant-based recipes,
    the row will be filtered out.

    Parameters:
    row (pandas.Series): Row of the DataFrame

    Returns:
    bool: True if animal emissions are greater than or equal to plant emissions, False otherwise
    """
    # Extract emission columns
    animal_emissions = [row[f'animal_{metric}'] for metric in ["GHG Emission (g) / 100g", "N lost (g) / 100g", 
                                                                "Freshwater Withdrawals (L) / 100g", 
                                                                "Stress-Weighted Water Use (L) / 100g", 
                                                                "Land Use (m^2) / 100g"]]
    plant_emissions = [row[f'plant_{metric}'] for metric in ["GHG Emission (g) / 100g", "N lost (g) / 100g", 
                                                              "Freshwater Withdrawals (L) / 100g", 
                                                              "Stress-Weighted Water Use (L) / 100g", 
                                                              "Land Use (m^2) / 100g"]]

    # Check if animal emissions are greater than or equal to plant emissions
    cnt = 1
    for animal, plant in zip(animal_emissions, plant_emissions):
        if animal < plant:
            cnt += 1
        if cnt > 2:
            return False
    return True
    
visualisations = visualisations[visualisations.apply(filter_emissions, axis=1)]

# Show the updated DataFrame
visualisations
# Out:
#                      animal_recipe animal_recipe_ID  \
# 29     HS|Bowl|Coconut Miso Salmon          R-73323
# 28   CLV|Chicken Tikka Masala|BOWL          R-68226
# 0            GRL|Burger|Salmon|AAD          R-44931
# 3      GRL|Chicken Burger|Maui|AAD          R-56454
# 27     SQR|Thai Green Fish Curry+1          R-57350
# 17   HC|Lemon Olive Oil Salmon|AAD          R-62715
# 19   SQR|Citrus Soy Pork Skewer +1          R-62631
# 16   FLX|Spicy Soy Salmon 100g|AAD          R-61967
# 20          SQR|Spicy Soy Salmon+1          R-41085
# 24  HS|Sesame Ginger Chicken|PLATE          R-73143
# 15            FLX|Shoyu Salmon|AAD          R-69236
# 21      CLV|Chicken Vindaloo|PLATE          R-44403
# 22      CLV|Chicken Vindaloo|PLATE          R-44403
# 30        HS|Pasta|Beef Stroganoff          R-50007
# 10      BNO|Taco|Chicken Tinga|2PC          R-67551
#
#                      plant_recipe plant_recipe_ID  \
# 29      HS|Bowl|Coconut Miso Tofu         R-73499
# 28     CLV|Tofu Tikka Masala|BOWL         R-68229
# 0        GRL|Burger|Jackfruit|AAD         R-53579
# 3        GRL|Burger|Jackfruit|AAD         R-53579
# 27     SQR|TOFU|Thai Green Curry          R-49260
# 17    HC|Lemon Olive Oil Tofu|AAD         R-73542
# 19  SQR|Citrus Mushroom Skewer +1         R-62639
# 16    FLX|Spicy Soy tofu 150g|AAD         R-62288
# 20           SQR|Spicy Soy Tofu+1         R-41089
# 24    HS|Sesame Ginger Tofu|PLATE         R-62138
# 15             FLX|Shoyu tofu|AAD         R-61956
# 21      FLX|Chickpea Vindaloo|AAD         R-56827
# 22          GLB|Chickpea Vindaloo         R-56827
# 30   HS|Pasta|Mushroom Stroganoff         R-67287
# 10  BNO|Taco|Jackfruit Tinga|2 PC         R-71310
#
#     animal_GHG Emission (g) / 100g  plant_GHG Emission (g) / 100g  \
# 29                          328.88                         147.49
# 28                          417.22                         204.23
# 0                           349.97                         131.20
# 3                           350.96                         131.20
# 27                          338.62                         230.13
# 17                          266.89                         134.80
# 19                          480.57                         154.09
# 16                          624.10                         158.27
# 20                          341.54                         152.23
# 24                          261.39                         148.38
# 15                          239.12                         130.18
# 21                          413.04                         124.59
# 22                          413.04                         124.59
# 30                          984.20                         134.71
# 10                          363.53                         236.13
#
#     animal_N lost (g) / 100g  plant_N lost (g) / 100g  \
# 29                      3.50                     0.58
# 28                      5.08                     1.07
# 0                       4.24                     0.86
# 3                       6.46                     0.86
# 27                      3.00                     0.40
# 17                      3.03                     0.64
# 19                      5.68                     1.19
# 16                      8.47                     0.70
# 20                      3.70                     0.50
# 24                      4.90                     0.69
# 15                      2.70                     0.60
# 21                      5.45                     0.79
# 22                      5.45                     0.79
# 30                      7.82                     1.20
# 10                      6.07                     2.07
#
#     animal_Freshwater Withdrawals (L) / 100g  \
# 29                                     92.00
# 28                                     76.63
# 0                                      95.86
# 3                                      37.24
# 27                                     83.59
# 17                                     95.22
# 19                                    113.47
# 16                                    186.12
# 20                                    101.29
# 24                                     38.96
# 15                                     82.08
# 21                                     76.17
# 22                                     76.17
# 30                                     51.21
# 10                                     40.31
#
#     plant_Freshwater Withdrawals (L) / 100g  \
# 29                                    23.09
# 28                                    38.63
# 0                                     14.18
# 3                                     14.18
# 27                                     0.91
# 17                                    38.02
# 19                                    56.52
# 16                                     2.34
# 20                                    24.90
# 24                                    28.19
# 15                                    36.91
# 21                                    28.73
# 22                                    28.73
# 30                                    18.87
# 10                                    24.79
#
#     animal_Stress-Weighted Water Use (L) / 100g  \
# 29                                       542.99
# 28                                      1785.27
# 0                                       1028.02
# 3                                        898.00
# 27                                       404.84
# 17                                       520.67
# 19                                      2842.20
# 16                                      1036.30
# 20                                       500.00
# 24                                       307.50
# 15                                       455.82
# 21                                      1940.51
# 22                                      1940.51
# 30                                      2077.49
# 10                                      1521.09
#
#     plant_Stress-Weighted Water Use (L) / 100g  animal_Land Use (m^2) / 100g  \
# 29                                      163.86                          0.47
# 28                                      595.57                          0.87
# 0                                       434.40                          0.70
# 3                                       434.40                          0.94
# 27                                       21.85                          0.60
# 17                                      213.54                          0.41
# 19                                     1076.23                          0.96
# 16                                       88.66                          0.98
# 20                                       90.84                          0.42
# 24                                      234.94                          0.68
# 15                                      215.05                          0.37
# 21                                      337.40                          0.96
# 22                                      337.40                          0.96
# 30                                      906.00                          2.86
# 10                                     1367.11                          0.72
#
#     plant_Land Use (m^2) / 100g
# 29                         0.27
# 28                         0.36
# 0                          0.30
# 3                          0.30
# 27                         0.22
# 17                         0.27
# 19                         0.26
# 16                         0.37
# 20                         0.21
# 24                         0.36
# 15                         0.26
# 21                         0.34
# 22                         0.34
# 30                         0.25
# 10                         0.41

# %%
signage_OK = pd.read_excel("signage_OK.xlsx")
signage_OK.drop_duplicates(inplace=True)
signage_OK.dropna(subset=["Station Name"], inplace=True)
signage_OK = signage_OK[["Item Name", "Internal Name"]]
signage_OK.reset_index(drop=True, inplace=True)
signage_OK
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/environmental-dashboard/env/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                         Item Name               Internal Name
# 0    AS YOU WOULD LIKE IT TO APPEAR ON NUTRISLICE      COPY AND PASTE FROM OC
# 1                            Apple Cinnamon Crepe    GRL|Crepe|Apple Cinnamon
# 2                        Apple Pie Overnight Oats   OATS|Over Night|Apple Pie
# 3                                Asparagus Quiche        VEG|Quiche|Asparagus
# 4                   Assorted Fruit Overnight Oats        OATS|Over Night|Base
# ..                                            ...                         ...
# 427                             Tropical Smoothie           SMOOTHIE|Tropical
# 428                           Wild Berry Smoothie         SMOOTHIE|Wild Berry
# 429                        Halloumi Avocado Bagel  GRL|Halloumi|Avocado|Bagel
# 430                          Ham and Cheese Bagel        GRL|Ham|Cheese|Bagel
# 431                           Smoked Salmon Bagel         BAGEL|Smoked Salmon
#
# [432 rows x 2 columns]

# %%
signage_gather = pd.read_excel("signage_gather.xlsx")
signage_gather.drop_duplicates(inplace=True)
signage_gather.dropna(subset=["Station Name"], inplace=True)
signage_gather = signage_gather[["Item Name", "Internal Name"]]
signage_gather.reset_index(drop=True, inplace=True)
signage_gather
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/environmental-dashboard/env/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                         Item Name  \
# 0    AS YOU WOULD LIKE IT TO APPEAR ON NUTRISLICE
# 1                                 Asparagus benny
# 2                      Asparagus poached egg bowl
# 3                           Avocado spinach benny
# 4                               B.E.L.T. sandwich
# ..                                            ...
# 458                              Roasted parsnips
# 459                                Roasted pepper
# 460                              Roasted zucchini
# 461                              Steamed broccoli
# 462                                           NaN
#
#                       Internal Name
# 0            COPY AND PASTE FROM OC
# 1           GRL|Benny|Asparagus|AAD
# 2    GRL|BOWL|Asparagus poached egg
# 3    GRL|Benny |Avocado spinach|AAD
# 4             GRL|Sand|B.E.L.T.|AAD
# ..                              ...
# 458              SIDE BAR|RATIO|AAD
# 459              SIDE BAR|RATIO|AAD
# 460              SIDE BAR|RATIO|AAD
# 461              SIDE BAR|RATIO|AAD
# 462                             NaN
#
# [463 rows x 2 columns]

# %%
signage_feast = pd.read_excel("signage_feast.xlsx")
signage_feast.drop_duplicates(inplace=True)
signage_feast.dropna(subset=["Station Name"], inplace=True)
signage_feast = signage_feast[["Item Name", "Internal Name"]]
signage_feast.reset_index(drop=True, inplace=True)
signage_feast
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/environmental-dashboard/env/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                         Item Name  \
# 0    AS YOU WOULD LIKE IT TO APPEAR ON NUTRISLICE
# 1                         APPLE CINNAMON PANCAKES
# 2                                    BACON STRIPS
# 3                         BANANA CARAMEL PANCAKES
# 4                              BLUEBERRY PANCAKES
# ..                                            ...
# 343                       HEARTY TOMATO VEGETABLE
# 344                            SPICY CORN CHOWDER
# 345                          BEEF BARLEY MUSHROOM
# 346             HOUSE MADE CREAM OF MUSHROOM SOUP
# 347                                           NaN
#
#                       Internal Name
# 0            COPY AND PASTE FROM OC
# 1        DNR|Pancake|Apple Cinnamon
# 2               DNR|Add Bacon|2 pcs
# 3     DNR|Pancake|BananaCaramel|2pc
# 4        DNR|Pancakes|Blueberry|2PC
# ..                              ...
# 343       SOUP|Goodly|Hearty tomato
# 344        SOUP|Goodly|Corn Chowder
# 345  SOUP|Goodly|Beef Barley Shroom
# 346  SOUP|House made|Cream Of Shroo
# 347                             NaN
#
# [348 rows x 2 columns]

# %%
for idx,row in visualisations.iterrows():
    for _,row2 in signage_OK.iterrows():
        if row["animal_recipe"] == row2["Internal Name"]:
            visualisations.loc[idx, "animal_recipe"] = row2["Item Name"].upper()
        if row["plant_recipe"] == row2["Internal Name"]:
            visualisations.loc[idx, "plant_recipe"] = row2["Item Name"].upper()
    for _,row3 in signage_gather.iterrows():
        if row["animal_recipe"] == row3["Internal Name"]:
            visualisations.loc[idx, "animal_recipe"] = row3["Item Name"].upper()
        if row["plant_recipe"] == row3["Internal Name"]:
            visualisations.loc[idx, "plant_recipe"] = row3["Item Name"].upper()
    for _,row4 in signage_feast.iterrows():
        if row["animal_recipe"] == row4["Internal Name"]:
            visualisations.loc[idx, "animal_recipe"] = row4["Item Name"].upper()
        if row["plant_recipe"] == row4["Internal Name"]:
            visualisations.loc[idx, "plant_recipe"] = row4["Item Name"].upper()

# %%
visualisations
# Out:
#                   animal_recipe animal_recipe_ID                 plant_recipe  \
# 29     COCONUT MISO SALMON BOWL          R-73323       COCONUT MISO TOFU BOWL
# 28    CHICKEN TIKKA MASALA BOWL          R-68226       TOFU TIKKA MASALA BOWL
# 0                 SALMON BURGER          R-44931             JACKFRUIT BURGER
# 3           MAUI CHICKEN BURGER          R-56454             JACKFRUIT BURGER
# 27  SQR|Thai Green Fish Curry+1          R-57350   SQR|TOFU|Thai Green Curry
# 17       SALMON LEMON OLIVE OIL          R-62715  HC|Lemon Olive Oil Tofu|AAD
# 19           CITRUS PORK SKEWER          R-62631       CITRUS MUSHROOM SKEWER
# 16             SPICY SOY SALMON          R-61967               SPICY SOY TOFU
# 20       SQR|Spicy Soy Salmon+1          R-41085         SQR|Spicy Soy Tofu+1
# 24  SESAME GINGER CHICKEN PLATE          R-73143     SESAME GINGER TOFU PLATE
# 15                 SHOYU SALMON          R-69236                   SHOYU TOFU
# 21       CHICKEN VINDALOO PLATE          R-44403            CHICKPEA VINDALOO
# 22       CHICKEN VINDALOO PLATE          R-44403            CHICKPEA VINDALOO
# 30              BEEF STROGANOFF          R-50007          MUSHROOM STROGANOFF
# 10           CHICKEN TINGA TACO          R-67551         JACKFRUIT TINGA TACO
#
#    plant_recipe_ID  animal_GHG Emission (g) / 100g  \
# 29         R-73499                          328.88
# 28         R-68229                          417.22
# 0          R-53579                          349.97
# 3          R-53579                          350.96
# 27         R-49260                          338.62
# 17         R-73542                          266.89
# 19         R-62639                          480.57
# 16         R-62288                          624.10
# 20         R-41089                          341.54
# 24         R-62138                          261.39
# 15         R-61956                          239.12
# 21         R-56827                          413.04
# 22         R-56827                          413.04
# 30         R-67287                          984.20
# 10         R-71310                          363.53
#
#     plant_GHG Emission (g) / 100g  animal_N lost (g) / 100g  \
# 29                         147.49                      3.50
# 28                         204.23                      5.08
# 0                          131.20                      4.24
# 3                          131.20                      6.46
# 27                         230.13                      3.00
# 17                         134.80                      3.03
# 19                         154.09                      5.68
# 16                         158.27                      8.47
# 20                         152.23                      3.70
# 24                         148.38                      4.90
# 15                         130.18                      2.70
# 21                         124.59                      5.45
# 22                         124.59                      5.45
# 30                         134.71                      7.82
# 10                         236.13                      6.07
#
#     plant_N lost (g) / 100g  animal_Freshwater Withdrawals (L) / 100g  \
# 29                     0.58                                     92.00
# 28                     1.07                                     76.63
# 0                      0.86                                     95.86
# 3                      0.86                                     37.24
# 27                     0.40                                     83.59
# 17                     0.64                                     95.22
# 19                     1.19                                    113.47
# 16                     0.70                                    186.12
# 20                     0.50                                    101.29
# 24                     0.69                                     38.96
# 15                     0.60                                     82.08
# 21                     0.79                                     76.17
# 22                     0.79                                     76.17
# 30                     1.20                                     51.21
# 10                     2.07                                     40.31
#
#     plant_Freshwater Withdrawals (L) / 100g  \
# 29                                    23.09
# 28                                    38.63
# 0                                     14.18
# 3                                     14.18
# 27                                     0.91
# 17                                    38.02
# 19                                    56.52
# 16                                     2.34
# 20                                    24.90
# 24                                    28.19
# 15                                    36.91
# 21                                    28.73
# 22                                    28.73
# 30                                    18.87
# 10                                    24.79
#
#     animal_Stress-Weighted Water Use (L) / 100g  \
# 29                                       542.99
# 28                                      1785.27
# 0                                       1028.02
# 3                                        898.00
# 27                                       404.84
# 17                                       520.67
# 19                                      2842.20
# 16                                      1036.30
# 20                                       500.00
# 24                                       307.50
# 15                                       455.82
# 21                                      1940.51
# 22                                      1940.51
# 30                                      2077.49
# 10                                      1521.09
#
#     plant_Stress-Weighted Water Use (L) / 100g  animal_Land Use (m^2) / 100g  \
# 29                                      163.86                          0.47
# 28                                      595.57                          0.87
# 0                                       434.40                          0.70
# 3                                       434.40                          0.94
# 27                                       21.85                          0.60
# 17                                      213.54                          0.41
# 19                                     1076.23                          0.96
# 16                                       88.66                          0.98
# 20                                       90.84                          0.42
# 24                                      234.94                          0.68
# 15                                      215.05                          0.37
# 21                                      337.40                          0.96
# 22                                      337.40                          0.96
# 30                                      906.00                          2.86
# 10                                     1367.11                          0.72
#
#     plant_Land Use (m^2) / 100g
# 29                         0.27
# 28                         0.36
# 0                          0.30
# 3                          0.30
# 27                         0.22
# 17                         0.27
# 19                         0.26
# 16                         0.37
# 20                         0.21
# 24                         0.36
# 15                         0.26
# 21                         0.34
# 22                         0.34
# 30                         0.25
# 10                         0.41

# %%
visualisations.to_csv("data/similar_recipes.csv", index=False)

# %%
# sns.set_theme(style="whitegrid")

# # Create a color palette for animal vs plant-based recipes
# colors = ['#FF6F61', '#88B04B']  # Coral for animal, green for plant

# # Function to create a bar chart for a given metric
# def plot_comparison(metric, ylabel, title):
#     plt.figure(figsize=(10, 6))
    
#     # Bar plot for the selected metric
#     sns.barplot(x='animal_recipe', y=f'animal_{metric}', data=visualisations, color=colors[0], label='Animal-based')
#     sns.barplot(x='animal_recipe', y=f'plant_{metric}', data=visualisations, color=colors[1], label='Plant-based')
    
#     # Set plot labels and title
#     plt.ylabel(ylabel)
#     plt.title(title)
#     plt.xticks(rotation=45, ha='right')
#     plt.legend(loc='upper right')
    
#     # Annotate each bar with the exact value
#     for idx, row in visualisations.iterrows():
#         animal_val = row[f'animal_{metric}']
#         plant_val = row[f'plant_{metric}']
#         plt.text(idx, animal_val + 10, f'{animal_val:.2f}', color='black', ha="center")
#         plt.text(idx, plant_val + 10, f'{plant_val:.2f}', color='black', ha="center")
    
#     plt.tight_layout()
#     plt.show()

# # Plot comparisons for each environmental metric
# plot_comparison("GHG Emission (g) / 100g", "GHG Emission (g) per 100g", "GHG Emissions: Animal-based vs Plant-based Recipes")
# plot_comparison("N lost (g) / 100g", "Nitrogen Lost (g) per 100g", "Nitrogen Lost: Animal-based vs Plant-based Recipes")
# plot_comparison("Freshwater Withdrawals (L) / 100g", "Freshwater Withdrawals (L) per 100g", "Freshwater Withdrawals: Animal-based vs Plant-based Recipes")
# plot_comparison("Stress-Weighted Water Use (L) / 100g", "Stress-Weighted Water Use (L) per 100g", "Stress-Weighted Water Use: Animal-based vs Plant-based Recipes")
# plot_comparison("Land Use (m^2) / 100g", "Land Use (m²) per 100g", "Land Use: Animal-based vs Plant-based Recipes")
